# %%
import numpy as np
import pandas as pd
import pickle as pkl

import random
import requests
import re
import os
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException, TimeoutException, WebDriverException

# %% [markdown]
# ### Set up ChromeDriver for Selenium

# %%
chromedriver = "C:\\Users\\Daniela\\chromedriver\\chromedriver.exe"
os.environ["webdriver.chrome.driver"] = chromedriver

# %% [markdown]
# We want to get the links for games directly to save the trouble of having Selenium click on links later on.

# %%
# Create an empty list to collect game links.
game_links = []

# %%
# The range is just the number of pages showed on Metacritic.

for i in range(157):
    url = f'http://www.metacritic.com/browse/games/score/metascore/all/all/filtered?sort=desc&page={i}'
    
    driver = webdriver.Chrome(chromedriver)
    driver.get(url)
    
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    
    tags = soup.find_all('div', attrs={'class':'product_item product_title'})
    
    for tag in tags:
        link = tag.find('a')['href']
        game_links.append(link)
    
    print(f'Finished retrieving links on page number {i}')
# Out:
# Finished retrieving links on page number 0
# Finished retrieving links on page number 1
# Finished retrieving links on page number 2
# Finished retrieving links on page number 3
# Finished retrieving links on page number 4
# Finished retrieving links on page number 5
# Finished retrieving links on page number 6
# Finished retrieving links on page number 7
# Finished retrieving links on page number 8
# Finished retrieving links on page number 9
# Finished retrieving links on page number 10
# Finished retrieving links on page number 11
# Finished retrieving links on page number 12
# Finished retrieving links on page number 13
# Finished retrieving links on page number 14
# Finished retrieving links on page number 15
# Finished retrieving links on page number 16
# Finished retrieving links on page number 17
# Finished retrieving links on page number 18
# Finished retrieving links on page number 19
# Finished retrieving links on page number 20
# Finished retrieving links on page number 21
# Finished retrieving links on page number 22
# Finished retrieving links on page number 23
# Finished retrieving links on page number 24
# Finished retrieving links on page number 25
# Finished retrieving links on page number 26
# Finished retrieving links on page number 27
# Finished retrieving links on page number 28
# Finished retrieving links on page number 29
# Finished retrieving links on page number 30
# Finished retrieving links on page number 31
# Finished retrieving links on page number 32
# Finished retrieving links on page number 33
# Finished retrieving links on page number 34
# Finished retrieving links on page number 35
# Finished retrieving links on page number 36
# Finished retrieving links on page number 37
# Finished retrieving links on page number 38
# Finished retrieving links on page number 39
# Finished retrieving links on page number 40
# Finished retrieving links on page number 41
# Finished retrieving links on page number 42
# Finished retrieving links on page number 43
# Finished retrieving links on page number 44
# Finished retrieving links on page number 45
# Finished retrieving links on page number 46
# Finished retrieving links on page number 47
# Finished retrieving links on page number 48
# Finished retrieving links on page number 49
# Finished retrieving links on page number 50
# Finished retrieving links on page number 51
# Finished retrieving links on page number 52
# Finished retrieving links on page number 53
# Finished retrieving links on page number 54
# Finished retrieving links on page number 55
# Finished retrieving links on page number 56
# Finished retrieving links on page number 57
# Finished retrieving links on page number 58
# Finished retrieving links on page number 59
# Finished retrieving links on page number 60
# Finished retrieving links on page number 61
# Finished retrieving links on page number 62
# Finished retrieving links on page number 63
# Finished retrieving links on page number 64
# Finished retrieving links on page number 65
# Finished retrieving links on page number 66
# Finished retrieving links on page number 67
# Finished retrieving links on page number 68
# Finished retrieving links on page number 69
# Finished retrieving links on page number 70
# Finished retrieving links on page number 71
# Finished retrieving links on page number 72
# Finished retrieving links on page number 73
# Finished retrieving links on page number 74
# Finished retrieving links on page number 75
# Finished retrieving links on page number 76
# Finished retrieving links on page number 77
# Finished retrieving links on page number 78
# Finished retrieving links on page number 79
# Finished retrieving links on page number 80
# Finished retrieving links on page number 81
# Finished retrieving links on page number 82
# Finished retrieving links on page number 83
# Finished retrieving links on page number 84
# Finished retrieving links on page number 85
# Finished retrieving links on page number 86
# Finished retrieving links on page number 87
# Finished retrieving links on page number 88
# Finished retrieving links on page number 89
# Finished retrieving links on page number 90
# Finished retrieving links on page number 91
# Finished retrieving links on page number 92
# Finished retrieving links on page number 93
# Finished retrieving links on page number 94
# Finished retrieving links on page number 95
# Finished retrieving links on page number 96
# Finished retrieving links on page number 97
# Finished retrieving links on page number 98
# Finished retrieving links on page number 99
# Finished retrieving links on page number 100
# Finished retrieving links on page number 101
# Finished retrieving links on page number 102
# Finished retrieving links on page number 103
# Finished retrieving links on page number 104
# Finished retrieving links on page number 105
# Finished retrieving links on page number 106
# Finished retrieving links on page number 107
# Finished retrieving links on page number 108
# Finished retrieving links on page number 109
# Finished retrieving links on page number 110
# Finished retrieving links on page number 111
# Finished retrieving links on page number 112
# Finished retrieving links on page number 113
# Finished retrieving links on page number 114
# Finished retrieving links on page number 115
# Finished retrieving links on page number 116
# Finished retrieving links on page number 117
# Finished retrieving links on page number 118
# Finished retrieving links on page number 119
# Finished retrieving links on page number 120
# Finished retrieving links on page number 121
# Finished retrieving links on page number 122
# Finished retrieving links on page number 123
# Finished retrieving links on page number 124
# Finished retrieving links on page number 125
# Finished retrieving links on page number 126
# Finished retrieving links on page number 127
# Finished retrieving links on page number 128
# Finished retrieving links on page number 129
# Finished retrieving links on page number 130
# Finished retrieving links on page number 131
# Finished retrieving links on page number 132
# Finished retrieving links on page number 133
# Finished retrieving links on page number 134
# Finished retrieving links on page number 135
# Finished retrieving links on page number 136
# Finished retrieving links on page number 137
# Finished retrieving links on page number 138
# Finished retrieving links on page number 139
# Finished retrieving links on page number 140
# Finished retrieving links on page number 141
# Finished retrieving links on page number 142
# Finished retrieving links on page number 143
# Finished retrieving links on page number 144
# Finished retrieving links on page number 145
# Finished retrieving links on page number 146
# Finished retrieving links on page number 147
# Finished retrieving links on page number 148
# Finished retrieving links on page number 149
# Finished retrieving links on page number 150
# Finished retrieving links on page number 151
# Finished retrieving links on page number 152
# Finished retrieving links on page number 153
# Finished retrieving links on page number 154
# Finished retrieving links on page number 155
# Finished retrieving links on page number 156

# %% [markdown]
# For each game (using the game links we gathered), gather the following information:
#
# - Game Title
# - Release Year
# - Publisher
# - Genre
# - Platform
# - Metascore (aka. Review score for game)
# - Average User Score
# - Number of Players (that can play the game)

# %%
# First, since all the links obtained are part of an URL. Need to fix that.

full_game_links = ['https://www.metacritic.com' + x for x in game_links]

# %%
title = []
release_year = []
publisher = []
genre = []
platform = []
metascore = []
avg_userscore = []
no_players = []

# %%
# Set up scraper

link_count = 0 #to keep track of how many links the scraper has gone through

for link in full_game_links:
    driver = webdriver.Chrome(chromedriver)
    driver.implicitly_wait(3) #add this so we don't need to wait for all webpage elements to load.
    driver.get(link)

    link_count += 1
    
    soup = BeautifulSoup(driver.page_source, 'html.parser')

    # get game title
    if soup.find('h1') == None:
        title.append('page not found')
    else:
        title.append(soup.find('h1').text)

    # get release year of game
    if soup.find('span', attrs={'class':'data', 'itemprop':'datePublished'}) == None:
        release_year.append('not specified')
    else:
        release_year.append(int(soup.find('span', attrs={'class':'data', 'itemprop':'datePublished'}).text[-4:]))

    # get publisher/developer of game
    if soup.find('li', attrs={'class':'summary_detail developer'}) == None:
        publisher.append('not specified')
    else:
        publisher.append(soup.find('li', attrs={'class':'summary_detail developer'}).text.replace('Developer:','').replace('\n','').replace(' ',''))

    # get genre(s) of game
    if len(soup.find_all('span', attrs={'class':'data', 'itemprop':'genre'})) == 1:
        genre.append(soup.find_all('span', attrs={'class':'data', 'itemprop':'genre'}).text)
    elif len(soup.find_all('span', attrs={'class':'data', 'itemprop':'genre'})) == 0:
        genre.append('no genre')
    else:    
        multi_genres = ';'.join([genre.text for genre in soup.find_all('span', attrs={'class':'data', 'itemprop':'genre'})])
        genre.append(multi_genres)

    # get platform of game
    if soup.find('span', attrs={'itemprop':'device'}) == None:
        platform.append('not specified')
    else:
        platform.append(soup.find('span', attrs={'itemprop':'device'}).text.replace('\n','').replace(' ',''))

    # get metascore of game
    if soup.find('span', attrs={'itemprop':'ratingValue'}) == None:
        metascore.append('not specified')
    else:
        metascore.append(soup.find('span', attrs={'itemprop':'ratingValue'}).text)

    # get average userscore of game
    if soup.find('div', attrs={'class':'userscore_wrap feature_userscore'}) == None:
        avg_userscore.append('not specified')
    else:
        avg_userscore.append(soup.find('div', attrs={'class':'userscore_wrap feature_userscore'}).text.replace('\nUser Score\n\n','')[0:3])

    # get the number of players that can play the game
    if soup.find('li', attrs={'class':'summary_detail product_players'}) == None:
        no_players.append('not specified')
    else:
        no_players.append(soup.find('li', attrs={'class':'summary_detail product_players'}).text.replace('\n# of players:\n','').replace('\n',''))

    print(f'Finished gathering Link # {link_count}, title: {len(title)}, year: {len(release_year)}, publisher: {len(publisher)}')
    print(f'genre: {len(genre)}, platform: {len(platform)}, metascore: {len(metascore)}, userscore: {len(avg_userscore)}, no_players: {len(no_players)}')
    
    driver.quit()
# Out:
# Finished gathering Link # 1, title: 1, year: 1, publisher: 1
# genre: 1, platform: 1, metascore: 1, userscore: 1, no_players: 1
# Finished gathering Link # 2, title: 2, year: 2, publisher: 2
# genre: 2, platform: 2, metascore: 2, userscore: 2, no_players: 2
# Finished gathering Link # 3, title: 3, year: 3, publisher: 3
# genre: 3, platform: 3, metascore: 3, userscore: 3, no_players: 3
# Finished gathering Link # 4, title: 4, year: 4, publisher: 4
# genre: 4, platform: 4, metascore: 4, userscore: 4, no_players: 4
# Finished gathering Link # 5, title: 5, year: 5, publisher: 5
# genre: 5, platform: 5, metascore: 5, userscore: 5, no_players: 5
# Finished gathering Link # 6, title: 6, year: 6, publisher: 6
# genre: 6, platform: 6, metascore: 6, userscore: 6, no_players: 6
# Finished gathering Link # 7, title: 7, year: 7, publisher: 7
# genre: 7, platform: 7, metascore: 7, userscore: 7, no_players: 7
# Finished gathering Link # 8, title: 8, year: 8, publisher: 8
# genre: 8, platform: 8, metascore: 8, userscore: 8, no_players: 8
# Finished gathering Link # 9, title: 9, year: 9, publisher: 9
# genre: 9, platform: 9, metascore: 9, userscore: 9, no_players: 9
# Finished gathering Link # 10, title: 10, year: 10, publisher: 10
# genre: 10, platform: 10, metascore: 10, userscore: 10, no_players: 10
# Finished gathering Link # 11, title: 11, year: 11, publisher: 11
# genre: 11, platform: 11, metascore: 11, userscore: 11, no_players: 11
# Finished gathering Link # 12, title: 12, year: 12, publisher: 12
# genre: 12, platform: 12, metascore: 12, userscore: 12, no_players: 12
# Finished gathering Link # 13, title: 13, year: 13, publisher: 13
# genre: 13, platform: 13, metascore: 13, userscore: 13, no_players: 13
# Finished gathering Link # 14, title: 14, year: 14, publisher: 14
# genre: 14, platform: 14, metascore: 14, userscore: 14, no_players: 14
# Finished gathering Link # 15, title: 15, year: 15, publisher: 15
# genre: 15, platform: 15, metascore: 15, userscore: 15, no_players: 15
# Finished gathering Link # 16, title: 16, year: 16, publisher: 16
# genre: 16, platform: 16, metascore: 16, userscore: 16, no_players: 16
# Finished gathering Link # 17, title: 17, year: 17, publisher: 17
# genre: 17, platform: 17, metascore: 17, userscore: 17, no_players: 17
# Finished gathering Link # 18, title: 18, year: 18, publisher: 18
# genre: 18, platform: 18, metascore: 18, userscore: 18, no_players: 18
# Finished gathering Link # 19, title: 19, year: 19, publisher: 19
# genre: 19, platform: 19, metascore: 19, userscore: 19, no_players: 19
# Finished gathering Link # 20, title: 20, year: 20, publisher: 20
# genre: 20, platform: 20, metascore: 20, userscore: 20, no_players: 20
# Finished gathering Link # 21, title: 21, year: 21, publisher: 21
# genre: 21, platform: 21, metascore: 21, userscore: 21, no_players: 21
# Finished gathering Link # 22, title: 22, year: 22, publisher: 22
# genre: 22, platform: 22, metascore: 22, userscore: 22, no_players: 22
# Finished gathering Link # 23, title: 23, year: 23, publisher: 23
# genre: 23, platform: 23, metascore: 23, userscore: 23, no_players: 23
# Finished gathering Link # 24, title: 24, year: 24, publisher: 24
# genre: 24, platform: 24, metascore: 24, userscore: 24, no_players: 24
# Finished gathering Link # 25, title: 25, year: 25, publisher: 25
# genre: 25, platform: 25, metascore: 25, userscore: 25, no_players: 25
# Finished gathering Link # 26, title: 26, year: 26, publisher: 26
# genre: 26, platform: 26, metascore: 26, userscore: 26, no_players: 26
# Finished gathering Link # 27, title: 27, year: 27, publisher: 27
# genre: 27, platform: 27, metascore: 27, userscore: 27, no_players: 27
# Finished gathering Link # 28, title: 28, year: 28, publisher: 28
# genre: 28, platform: 28, metascore: 28, userscore: 28, no_players: 28
# Finished gathering Link # 29, title: 29, year: 29, publisher: 29
# genre: 29, platform: 29, metascore: 29, userscore: 29, no_players: 29
# Finished gathering Link # 30, title: 30, year: 30, publisher: 30
# genre: 30, platform: 30, metascore: 30, userscore: 30, no_players: 30
# Finished gathering Link # 31, title: 31, year: 31, publisher: 31
# genre: 31, platform: 31, metascore: 31, userscore: 31, no_players: 31
# Finished gathering Link # 32, title: 32, year: 32, publisher: 32
# genre: 32, platform: 32, metascore: 32, userscore: 32, no_players: 32
# Finished gathering Link # 33, title: 33, year: 33, publisher: 33
# genre: 33, platform: 33, metascore: 33, userscore: 33, no_players: 33
# Finished gathering Link # 34, title: 34, year: 34, publisher: 34
# genre: 34, platform: 34, metascore: 34, userscore: 34, no_players: 34
# Finished gathering Link # 35, title: 35, year: 35, publisher: 35
# genre: 35, platform: 35, metascore: 35, userscore: 35, no_players: 35
# Finished gathering Link # 36, title: 36, year: 36, publisher: 36
# genre: 36, platform: 36, metascore: 36, userscore: 36, no_players: 36
# Finished gathering Link # 37, title: 37, year: 37, publisher: 37
# genre: 37, platform: 37, metascore: 37, userscore: 37, no_players: 37
# Finished gathering Link # 38, title: 38, year: 38, publisher: 38
# genre: 38, platform: 38, metascore: 38, userscore: 38, no_players: 38
# Finished gathering Link # 39, title: 39, year: 39, publisher: 39
# genre: 39, platform: 39, metascore: 39, userscore: 39, no_players: 39
# Finished gathering Link # 40, title: 40, year: 40, publisher: 40
# genre: 40, platform: 40, metascore: 40, userscore: 40, no_players: 40
# Finished gathering Link # 41, title: 41, year: 41, publisher: 41
# genre: 41, platform: 41, metascore: 41, userscore: 41, no_players: 41
# Finished gathering Link # 42, title: 42, year: 42, publisher: 42
# genre: 42, platform: 42, metascore: 42, userscore: 42, no_players: 42
# Finished gathering Link # 43, title: 43, year: 43, publisher: 43
# genre: 43, platform: 43, metascore: 43, userscore: 43, no_players: 43
# Finished gathering Link # 44, title: 44, year: 44, publisher: 44
# genre: 44, platform: 44, metascore: 44, userscore: 44, no_players: 44
# Finished gathering Link # 45, title: 45, year: 45, publisher: 45
# genre: 45, platform: 45, metascore: 45, userscore: 45, no_players: 45
# Finished gathering Link # 46, title: 46, year: 46, publisher: 46
# genre: 46, platform: 46, metascore: 46, userscore: 46, no_players: 46
# Finished gathering Link # 47, title: 47, year: 47, publisher: 47
# genre: 47, platform: 47, metascore: 47, userscore: 47, no_players: 47
# Finished gathering Link # 48, title: 48, year: 48, publisher: 48
# genre: 48, platform: 48, metascore: 48, userscore: 48, no_players: 48
# Finished gathering Link # 49, title: 49, year: 49, publisher: 49
# genre: 49, platform: 49, metascore: 49, userscore: 49, no_players: 49
# Finished gathering Link # 50, title: 50, year: 50, publisher: 50
# genre: 50, platform: 50, metascore: 50, userscore: 50, no_players: 50
# Finished gathering Link # 51, title: 51, year: 51, publisher: 51
# genre: 51, platform: 51, metascore: 51, userscore: 51, no_players: 51
# Finished gathering Link # 52, title: 52, year: 52, publisher: 52
# genre: 52, platform: 52, metascore: 52, userscore: 52, no_players: 52
# Finished gathering Link # 53, title: 53, year: 53, publisher: 53
# genre: 53, platform: 53, metascore: 53, userscore: 53, no_players: 53
# Finished gathering Link # 54, title: 54, year: 54, publisher: 54
# genre: 54, platform: 54, metascore: 54, userscore: 54, no_players: 54
# Finished gathering Link # 55, title: 55, year: 55, publisher: 55
# genre: 55, platform: 55, metascore: 55, userscore: 55, no_players: 55
# Finished gathering Link # 56, title: 56, year: 56, publisher: 56
# genre: 56, platform: 56, metascore: 56, userscore: 56, no_players: 56
# Finished gathering Link # 57, title: 57, year: 57, publisher: 57
# genre: 57, platform: 57, metascore: 57, userscore: 57, no_players: 57
# Finished gathering Link # 58, title: 58, year: 58, publisher: 58
# genre: 58, platform: 58, metascore: 58, userscore: 58, no_players: 58
# Finished gathering Link # 59, title: 59, year: 59, publisher: 59
# genre: 59, platform: 59, metascore: 59, userscore: 59, no_players: 59
# Finished gathering Link # 60, title: 60, year: 60, publisher: 60
# genre: 60, platform: 60, metascore: 60, userscore: 60, no_players: 60
# Finished gathering Link # 61, title: 61, year: 61, publisher: 61
# genre: 61, platform: 61, metascore: 61, userscore: 61, no_players: 61
# Finished gathering Link # 62, title: 62, year: 62, publisher: 62
# genre: 62, platform: 62, metascore: 62, userscore: 62, no_players: 62
# Finished gathering Link # 63, title: 63, year: 63, publisher: 63
# genre: 63, platform: 63, metascore: 63, userscore: 63, no_players: 63
# Finished gathering Link # 64, title: 64, year: 64, publisher: 64
# genre: 64, platform: 64, metascore: 64, userscore: 64, no_players: 64
# Finished gathering Link # 65, title: 65, year: 65, publisher: 65
# genre: 65, platform: 65, metascore: 65, userscore: 65, no_players: 65
# Finished gathering Link # 66, title: 66, year: 66, publisher: 66
# genre: 66, platform: 66, metascore: 66, userscore: 66, no_players: 66
# Finished gathering Link # 67, title: 67, year: 67, publisher: 67
# genre: 67, platform: 67, metascore: 67, userscore: 67, no_players: 67
# Finished gathering Link # 68, title: 68, year: 68, publisher: 68
# genre: 68, platform: 68, metascore: 68, userscore: 68, no_players: 68
# Finished gathering Link # 69, title: 69, year: 69, publisher: 69
# genre: 69, platform: 69, metascore: 69, userscore: 69, no_players: 69
# Finished gathering Link # 70, title: 70, year: 70, publisher: 70
# genre: 70, platform: 70, metascore: 70, userscore: 70, no_players: 70
# Finished gathering Link # 71, title: 71, year: 71, publisher: 71
# genre: 71, platform: 71, metascore: 71, userscore: 71, no_players: 71
# Finished gathering Link # 72, title: 72, year: 72, publisher: 72
# genre: 72, platform: 72, metascore: 72, userscore: 72, no_players: 72
# Finished gathering Link # 73, title: 73, year: 73, publisher: 73
# genre: 73, platform: 73, metascore: 73, userscore: 73, no_players: 73
# Finished gathering Link # 74, title: 74, year: 74, publisher: 74
# genre: 74, platform: 74, metascore: 74, userscore: 74, no_players: 74
# Finished gathering Link # 75, title: 75, year: 75, publisher: 75
# genre: 75, platform: 75, metascore: 75, userscore: 75, no_players: 75
# Finished gathering Link # 76, title: 76, year: 76, publisher: 76
# genre: 76, platform: 76, metascore: 76, userscore: 76, no_players: 76
# Finished gathering Link # 77, title: 77, year: 77, publisher: 77
# genre: 77, platform: 77, metascore: 77, userscore: 77, no_players: 77
# Finished gathering Link # 78, title: 78, year: 78, publisher: 78
# genre: 78, platform: 78, metascore: 78, userscore: 78, no_players: 78
# Finished gathering Link # 79, title: 79, year: 79, publisher: 79
# genre: 79, platform: 79, metascore: 79, userscore: 79, no_players: 79
# Finished gathering Link # 80, title: 80, year: 80, publisher: 80
# genre: 80, platform: 80, metascore: 80, userscore: 80, no_players: 80
# Finished gathering Link # 81, title: 81, year: 81, publisher: 81
# genre: 81, platform: 81, metascore: 81, userscore: 81, no_players: 81
# Finished gathering Link # 82, title: 82, year: 82, publisher: 82
# genre: 82, platform: 82, metascore: 82, userscore: 82, no_players: 82
# Finished gathering Link # 83, title: 83, year: 83, publisher: 83
# genre: 83, platform: 83, metascore: 83, userscore: 83, no_players: 83
# Finished gathering Link # 84, title: 84, year: 84, publisher: 84
# genre: 84, platform: 84, metascore: 84, userscore: 84, no_players: 84
# Finished gathering Link # 85, title: 85, year: 85, publisher: 85
# genre: 85, platform: 85, metascore: 85, userscore: 85, no_players: 85
# Finished gathering Link # 86, title: 86, year: 86, publisher: 86
# genre: 86, platform: 86, metascore: 86, userscore: 86, no_players: 86
# Finished gathering Link # 87, title: 87, year: 87, publisher: 87
# genre: 87, platform: 87, metascore: 87, userscore: 87, no_players: 87
# Finished gathering Link # 88, title: 88, year: 88, publisher: 88
# genre: 88, platform: 88, metascore: 88, userscore: 88, no_players: 88
# Finished gathering Link # 89, title: 89, year: 89, publisher: 89
# genre: 89, platform: 89, metascore: 89, userscore: 89, no_players: 89
# Finished gathering Link # 90, title: 90, year: 90, publisher: 90
# genre: 90, platform: 90, metascore: 90, userscore: 90, no_players: 90
# Finished gathering Link # 91, title: 91, year: 91, publisher: 91
# genre: 91, platform: 91, metascore: 91, userscore: 91, no_players: 91
# Finished gathering Link # 92, title: 92, year: 92, publisher: 92
# genre: 92, platform: 92, metascore: 92, userscore: 92, no_players: 92
# Finished gathering Link # 93, title: 93, year: 93, publisher: 93
# genre: 93, platform: 93, metascore: 93, userscore: 93, no_players: 93
# Finished gathering Link # 94, title: 94, year: 94, publisher: 94
# genre: 94, platform: 94, metascore: 94, userscore: 94, no_players: 94
# Finished gathering Link # 95, title: 95, year: 95, publisher: 95
# genre: 95, platform: 95, metascore: 95, userscore: 95, no_players: 95
# Finished gathering Link # 96, title: 96, year: 96, publisher: 96
# genre: 96, platform: 96, metascore: 96, userscore: 96, no_players: 96
# Finished gathering Link # 97, title: 97, year: 97, publisher: 97
# genre: 97, platform: 97, metascore: 97, userscore: 97, no_players: 97
# Finished gathering Link # 98, title: 98, year: 98, publisher: 98
# genre: 98, platform: 98, metascore: 98, userscore: 98, no_players: 98
# Finished gathering Link # 99, title: 99, year: 99, publisher: 99
# genre: 99, platform: 99, metascore: 99, userscore: 99, no_players: 99
# Finished gathering Link # 100, title: 100, year: 100, publisher: 100
# genre: 100, platform: 100, metascore: 100, userscore: 100, no_players: 100
# Finished gathering Link # 101, title: 101, year: 101, publisher: 101
# genre: 101, platform: 101, metascore: 101, userscore: 101, no_players: 101
# Finished gathering Link # 102, title: 102, year: 102, publisher: 102
# genre: 102, platform: 102, metascore: 102, userscore: 102, no_players: 102
# Finished gathering Link # 103, title: 103, year: 103, publisher: 103
# genre: 103, platform: 103, metascore: 103, userscore: 103, no_players: 103
# Finished gathering Link # 104, title: 104, year: 104, publisher: 104
# genre: 104, platform: 104, metascore: 104, userscore: 104, no_players: 104
# Finished gathering Link # 105, title: 105, year: 105, publisher: 105
# genre: 105, platform: 105, metascore: 105, userscore: 105, no_players: 105
# Finished gathering Link # 106, title: 106, year: 106, publisher: 106
# genre: 106, platform: 106, metascore: 106, userscore: 106, no_players: 106
# Finished gathering Link # 107, title: 107, year: 107, publisher: 107
# genre: 107, platform: 107, metascore: 107, userscore: 107, no_players: 107
# Finished gathering Link # 108, title: 108, year: 108, publisher: 108
# genre: 108, platform: 108, metascore: 108, userscore: 108, no_players: 108
# Finished gathering Link # 109, title: 109, year: 109, publisher: 109
# genre: 109, platform: 109, metascore: 109, userscore: 109, no_players: 109
# Finished gathering Link # 110, title: 110, year: 110, publisher: 110
# genre: 110, platform: 110, metascore: 110, userscore: 110, no_players: 110
# Finished gathering Link # 111, title: 111, year: 111, publisher: 111
# genre: 111, platform: 111, metascore: 111, userscore: 111, no_players: 111
# Finished gathering Link # 112, title: 112, year: 112, publisher: 112
# genre: 112, platform: 112, metascore: 112, userscore: 112, no_players: 112
# Finished gathering Link # 113, title: 113, year: 113, publisher: 113
# genre: 113, platform: 113, metascore: 113, userscore: 113, no_players: 113
# Finished gathering Link # 114, title: 114, year: 114, publisher: 114
# genre: 114, platform: 114, metascore: 114, userscore: 114, no_players: 114
# Finished gathering Link # 115, title: 115, year: 115, publisher: 115
# genre: 115, platform: 115, metascore: 115, userscore: 115, no_players: 115
# Finished gathering Link # 116, title: 116, year: 116, publisher: 116
# genre: 116, platform: 116, metascore: 116, userscore: 116, no_players: 116
# Finished gathering Link # 117, title: 117, year: 117, publisher: 117
# genre: 117, platform: 117, metascore: 117, userscore: 117, no_players: 117
# Finished gathering Link # 118, title: 118, year: 118, publisher: 118
# genre: 118, platform: 118, metascore: 118, userscore: 118, no_players: 118
# Finished gathering Link # 119, title: 119, year: 119, publisher: 119
# genre: 119, platform: 119, metascore: 119, userscore: 119, no_players: 119
# Finished gathering Link # 120, title: 120, year: 120, publisher: 120
# genre: 120, platform: 120, metascore: 120, userscore: 120, no_players: 120
# Finished gathering Link # 121, title: 121, year: 121, publisher: 121
# genre: 121, platform: 121, metascore: 121, userscore: 121, no_players: 121
# Finished gathering Link # 122, title: 122, year: 122, publisher: 122
# genre: 122, platform: 122, metascore: 122, userscore: 122, no_players: 122
# Finished gathering Link # 123, title: 123, year: 123, publisher: 123
# genre: 123, platform: 123, metascore: 123, userscore: 123, no_players: 123
# Finished gathering Link # 124, title: 124, year: 124, publisher: 124
# genre: 124, platform: 124, metascore: 124, userscore: 124, no_players: 124
# Finished gathering Link # 125, title: 125, year: 125, publisher: 125
# genre: 125, platform: 125, metascore: 125, userscore: 125, no_players: 125
# Finished gathering Link # 126, title: 126, year: 126, publisher: 126
# genre: 126, platform: 126, metascore: 126, userscore: 126, no_players: 126
# Finished gathering Link # 127, title: 127, year: 127, publisher: 127
# genre: 127, platform: 127, metascore: 127, userscore: 127, no_players: 127
# Finished gathering Link # 128, title: 128, year: 128, publisher: 128
# genre: 128, platform: 128, metascore: 128, userscore: 128, no_players: 128
# Finished gathering Link # 129, title: 129, year: 129, publisher: 129
# genre: 129, platform: 129, metascore: 129, userscore: 129, no_players: 129
# Finished gathering Link # 130, title: 130, year: 130, publisher: 130
# genre: 130, platform: 130, metascore: 130, userscore: 130, no_players: 130
# Finished gathering Link # 131, title: 131, year: 131, publisher: 131
# genre: 131, platform: 131, metascore: 131, userscore: 131, no_players: 131
# Finished gathering Link # 132, title: 132, year: 132, publisher: 132
# genre: 132, platform: 132, metascore: 132, userscore: 132, no_players: 132
# Finished gathering Link # 133, title: 133, year: 133, publisher: 133
# genre: 133, platform: 133, metascore: 133, userscore: 133, no_players: 133
# Finished gathering Link # 134, title: 134, year: 134, publisher: 134
# genre: 134, platform: 134, metascore: 134, userscore: 134, no_players: 134
# Finished gathering Link # 135, title: 135, year: 135, publisher: 135
# genre: 135, platform: 135, metascore: 135, userscore: 135, no_players: 135
# Finished gathering Link # 136, title: 136, year: 136, publisher: 136
# genre: 136, platform: 136, metascore: 136, userscore: 136, no_players: 136
# Finished gathering Link # 137, title: 137, year: 137, publisher: 137
# genre: 137, platform: 137, metascore: 137, userscore: 137, no_players: 137
# Finished gathering Link # 138, title: 138, year: 138, publisher: 138
# genre: 138, platform: 138, metascore: 138, userscore: 138, no_players: 138
# Finished gathering Link # 139, title: 139, year: 139, publisher: 139
# genre: 139, platform: 139, metascore: 139, userscore: 139, no_players: 139
# Finished gathering Link # 140, title: 140, year: 140, publisher: 140
# genre: 140, platform: 140, metascore: 140, userscore: 140, no_players: 140
# Finished gathering Link # 141, title: 141, year: 141, publisher: 141
# genre: 141, platform: 141, metascore: 141, userscore: 141, no_players: 141
# Finished gathering Link # 142, title: 142, year: 142, publisher: 142
# genre: 142, platform: 142, metascore: 142, userscore: 142, no_players: 142
# Finished gathering Link # 143, title: 143, year: 143, publisher: 143
# genre: 143, platform: 143, metascore: 143, userscore: 143, no_players: 143
# Finished gathering Link # 144, title: 144, year: 144, publisher: 144
# genre: 144, platform: 144, metascore: 144, userscore: 144, no_players: 144
# Finished gathering Link # 145, title: 145, year: 145, publisher: 145
# genre: 145, platform: 145, metascore: 145, userscore: 145, no_players: 145
# Finished gathering Link # 146, title: 146, year: 146, publisher: 146
# genre: 146, platform: 146, metascore: 146, userscore: 146, no_players: 146
# Finished gathering Link # 147, title: 147, year: 147, publisher: 147
# genre: 147, platform: 147, metascore: 147, userscore: 147, no_players: 147
# Finished gathering Link # 148, title: 148, year: 148, publisher: 148
# genre: 148, platform: 148, metascore: 148, userscore: 148, no_players: 148
# Finished gathering Link # 149, title: 149, year: 149, publisher: 149
# genre: 149, platform: 149, metascore: 149, userscore: 149, no_players: 149
# Finished gathering Link # 150, title: 150, year: 150, publisher: 150
# genre: 150, platform: 150, metascore: 150, userscore: 150, no_players: 150
# Finished gathering Link # 151, title: 151, year: 151, publisher: 151
# genre: 151, platform: 151, metascore: 151, userscore: 151, no_players: 151
# Finished gathering Link # 152, title: 152, year: 152, publisher: 152
# genre: 152, platform: 152, metascore: 152, userscore: 152, no_players: 152
# Finished gathering Link # 153, title: 153, year: 153, publisher: 153
# genre: 153, platform: 153, metascore: 153, userscore: 153, no_players: 153
# Finished gathering Link # 154, title: 154, year: 154, publisher: 154
# genre: 154, platform: 154, metascore: 154, userscore: 154, no_players: 154
# Finished gathering Link # 155, title: 155, year: 155, publisher: 155
# genre: 155, platform: 155, metascore: 155, userscore: 155, no_players: 155
# Finished gathering Link # 156, title: 156, year: 156, publisher: 156
# genre: 156, platform: 156, metascore: 156, userscore: 156, no_players: 156
# Finished gathering Link # 157, title: 157, year: 157, publisher: 157
# genre: 157, platform: 157, metascore: 157, userscore: 157, no_players: 157
# Finished gathering Link # 158, title: 158, year: 158, publisher: 158
# genre: 158, platform: 158, metascore: 158, userscore: 158, no_players: 158
# Finished gathering Link # 159, title: 159, year: 159, publisher: 159
# genre: 159, platform: 159, metascore: 159, userscore: 159, no_players: 159
# Finished gathering Link # 160, title: 160, year: 160, publisher: 160
# genre: 160, platform: 160, metascore: 160, userscore: 160, no_players: 160
# Finished gathering Link # 161, title: 161, year: 161, publisher: 161
# genre: 161, platform: 161, metascore: 161, userscore: 161, no_players: 161
# Finished gathering Link # 162, title: 162, year: 162, publisher: 162
# genre: 162, platform: 162, metascore: 162, userscore: 162, no_players: 162
# Finished gathering Link # 163, title: 163, year: 163, publisher: 163
# genre: 163, platform: 163, metascore: 163, userscore: 163, no_players: 163
# Finished gathering Link # 164, title: 164, year: 164, publisher: 164
# genre: 164, platform: 164, metascore: 164, userscore: 164, no_players: 164
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-41-ecf15e0d87f3> in <module>()
#      10     link_count += 1
#      11
# ---> 12     soup = BeautifulSoup(driver.page_source, 'html.parser')
#      13
#      14     # get game title
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\selenium\webdriver\remote\webdriver.py in page_source(self)
#     677             driver.page_source
#     678         """
# --> 679         return self.execute(Command.GET_PAGE_SOURCE)['value']
#     680
#     681     def close(self):
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=69.0.3497.100)
#   (Driver info: chromedriver=2.42.591088 (7b2b2dca23cca0862f674758c9a3933e685c27d5),platform=Windows NT 10.0.17134 x86_64)

# %%
# Put all information collected in lists into a DataFrame.

df = pd.DataFrame(columns=['Title','Year','Publisher','Genre','Platform','Metascore','Avg_Userscore','No_Players'])
df['Title'] = title
df['Year'] = release_year
df['Publisher'] = publisher
df['Genre'] = genre
df['Platform'] = platform
df['Metascore'] = metascore
df['Avg_Userscore'] = avg_userscore
df['No_Players'] = no_players

# %%
# An quick shot of what the DataFrame should look like
df.head()
# Out:
#                                   Title           Year  \
# 0  The Legend of Zelda: Ocarina of Time  not specified
# 1              Tony Hawk's Pro Skater 2  not specified
# 2                   Grand Theft Auto IV  not specified
# 3                           SoulCalibur  not specified
# 4                   Grand Theft Auto IV  not specified
#
#                 Publisher     Genre       Platform Metascore Avg_Userscore  \
# 0                Nintendo  no genre  not specified        99           9.1
# 1  NeversoftEntertainment  no genre  not specified        98           7.4
# 2           RockstarNorth  no genre  not specified        98           7.5
# 3                   Namco  no genre  not specified        98           8.7
# 4           RockstarNorth  no genre  not specified        98           7.9
#
#   No_Players
# 0   1 Player
# 1       1-2
# 2   1 Player
# 3       1-2
# 4   1 Player

# %%
# Save all data with Pickle.

with open('final_game_general_data.pkl', 'wb') as picklefile:
    pkl.dump(df, picklefile)

# %% [markdown]
# The code below is another scraper for gathering user comments for each game scraped.

# %%
# All the game links that could not be accessed or found; do not need these.

df[df.Year == 'not specified']
# Out:
#                                            Title           Year  \
# 0           The Legend of Zelda: Ocarina of Time  not specified
# 1                       Tony Hawk's Pro Skater 2  not specified
# 2                            Grand Theft Auto IV  not specified
# 3                                    SoulCalibur  not specified
# 4                            Grand Theft Auto IV  not specified
# 5                             Super Mario Galaxy  not specified
# 6                           Super Mario Galaxy 2  not specified
# 7                             Grand Theft Auto V  not specified
# 8                             Grand Theft Auto V  not specified
# 9                             Grand Theft Auto V  not specified
# 10                      Tony Hawk's Pro Skater 2  not specified
# 11       The Legend of Zelda: Breath of the Wild  not specified
# 12                      Tony Hawk's Pro Skater 3  not specified
# 13                                  Perfect Dark  not specified
# 14                            Grand Theft Auto V  not specified
# 15                                 Metroid Prime  not specified
# 16                          Grand Theft Auto III  not specified
# 17                           Super Mario Odyssey  not specified
# 18                          Halo: Combat Evolved  not specified
# 19                                       NFL 2K1  not specified
# 20                                   Half-Life 2  not specified
# 21                            Grand Theft Auto V  not specified
# 22       The Legend of Zelda: Breath of the Wild  not specified
# 23                                      BioShock  not specified
# 24                                 GoldenEye 007  not specified
# 25                    Uncharted 2: Among Thieves  not specified
# 26                               Resident Evil 4  not specified
# 27                                The Orange Box  not specified
# 28                                The Orange Box  not specified
# 29                           Batman: Arkham City  not specified
# ..                                           ...            ...
# 134                                    Homeworld  not specified
# 135                                        Okami  not specified
# 136               The Elder Scrolls IV: Oblivion  not specified
# 137                                    Fallout 3  not specified
# 138                               Gears of War 2  not specified
# 139                               SoulCalibur II  not specified
# 140  World Soccer Winning Eleven 6 International  not specified
# 141                                      NFL 2K3  not specified
# 142                                Mass Effect 3  not specified
# 143         Metal Gear Solid V: The Phantom Pain  not specified
# 144                             Skies of Arcadia  not specified
# 145           The Legend of Zelda: Skyward Sword  not specified
# 146                     Mario Kart Super Circuit  not specified
# 147                                  Rock Band 3  not specified
# 148                                Viewtiful Joe  not specified
# 149                           Test Drive Le Mans  not specified
# 150                                      NBA 2K1  not specified
# 151           Castlevania: Symphony of the Night  not specified
# 152       Star Wars: Knights of the Old Republic  not specified
# 153                  Virtua Fighter 4: Evolution  not specified
# 154                   Uncharted 4: A Thief's End  not specified
# 155                                        Braid  not specified
# 156                                Mass Effect 3  not specified
# 157                                  Paper Mario  not specified
# 158                                   Wipeout XL  not specified
# 159                Grand Theft Auto: San Andreas  not specified
# 160                                       INSIDE  not specified
# 161                            World of Warcraft  not specified
# 162                Grand Theft Auto: San Andreas  not specified
# 163                              Flipnote Studio  not specified
#
#                             Publisher     Genre       Platform Metascore  \
# 0                            Nintendo  no genre  not specified        99
# 1              NeversoftEntertainment  no genre  not specified        98
# 2                       RockstarNorth  no genre  not specified        98
# 3                               Namco  no genre  not specified        98
# 4                       RockstarNorth  no genre  not specified        98
# 5                            Nintendo  no genre  not specified        97
# 6                    NintendoEADTokyo  no genre  not specified        97
# 7                       RockstarNorth  no genre  not specified        97
# 8                       RockstarNorth  no genre  not specified        97
# 9                       RockstarNorth  no genre  not specified        97
# 10                           Treyarch  no genre  not specified        97
# 11                           Nintendo  no genre  not specified        97
# 12             NeversoftEntertainment  no genre  not specified        97
# 13                           RareLtd.  no genre  not specified        97
# 14                      RockstarNorth  no genre  not specified        97
# 15                       RetroStudios  no genre  not specified        97
# 16                          DMADesign  no genre  not specified        97
# 17                           Nintendo  no genre  not specified        97
# 18                     BungieSoftware  no genre  not specified        97
# 19                     VisualConcepts  no genre  not specified        97
# 20                      ValveSoftware  no genre  not specified        96
# 21                      RockstarNorth  no genre  not specified        96
# 22                           Nintendo  no genre  not specified        96
# 23            IrrationalGames,2KMarin  no genre  not specified        96
# 24                           RareLtd.  no genre  not specified        96
# 25                         NaughtyDog  no genre  not specified        96
# 26                             Capcom  no genre  not specified        96
# 27                      ValveSoftware  no genre  not specified        96
# 28                      ValveSoftware  no genre  not specified        96
# 29                  RocksteadyStudios  no genre  not specified        96
# ..                                ...       ...            ...       ...
# 134                             Relic  no genre  not specified        93
# 135                      CloverStudio  no genre  not specified        93
# 136                         4JStudios  no genre  not specified        93
# 137               BethesdaGameStudios  no genre  not specified        93
# 138                         EpicGames  no genre  not specified        93
# 139                             Namco  no genre  not specified        93
# 140                              KCET  no genre  not specified        93
# 141                    VisualConcepts  no genre  not specified        93
# 142                           BioWare  no genre  not specified        93
# 143  KojimaProductions,MobyDickStudio  no genre  not specified        93
# 144                         Overworks  no genre  not specified        93
# 145                          Nintendo  no genre  not specified        93
# 146                IntelligentSystems  no genre  not specified        93
# 147              HarmonixMusicSystems  no genre  not specified        93
# 148                      CloverStudio  no genre  not specified        93
# 149                    MelbourneHouse  no genre  not specified        93
# 150                    VisualConcepts  no genre  not specified        93
# 151                            Konami  no genre  not specified        93
# 152                           BioWare  no genre  not specified        93
# 153                              Sega  no genre  not specified        93
# 154                        NaughtyDog  no genre  not specified        93
# 155       HotheadGames,NumberNoneInc.  no genre  not specified        93
# 156                           BioWare  no genre  not specified        93
# 157                IntelligentSystems  no genre  not specified        93
# 158                         Psygnosis  no genre  not specified        93
# 159                     RockstarNorth  no genre  not specified        93
# 160                          PLAYDEAD  no genre  not specified        93
# 161             BlizzardEntertainment  no genre  not specified        93
# 162                     RockstarNorth  no genre  not specified        93
# 163                          Nintendo  no genre  not specified        93
#
#     Avg_Userscore             No_Players
# 0             9.1               1 Player
# 1             7.4                   1-2
# 2             7.5               1 Player
# 3             8.7                   1-2
# 4             7.9               1 Player
# 5             9.0  No Online Multiplayer
# 6             9.1  No Online Multiplayer
# 7             7.8              Up to 30
# 8             8.3              Up to 16
# 9             8.3              Up to 16
# 10            6.2          not specified
# 11            8.5  No Online Multiplayer
# 12            7.5                   1-2
# 13            8.9          not specified
# 14            8.3              Up to 30
# 15            9.2               1 Player
# 16            8.5               1 Player
# 17            8.9  No Online Multiplayer
# 18            8.6                   1-4
# 19            6.4          not specified
# 20            9.1  No Online Multiplayer
# 21            7.7              Up to 32
# 22            8.2  No Online Multiplayer
# 23            8.9  No Online Multiplayer
# 24            9.1                   1-4
# 25            8.9  No Online Multiplayer
# 26            9.3               1 Player
# 27            8.8             16  Online
# 28            9.2             16  Online
# 29            8.7  No Online Multiplayer
# ..            ...                    ...
# 134           8.9                   1-8
# 135           9.1               1 Player
# 136           8.0  No Online Multiplayer
# 137           8.5  No Online Multiplayer
# 138           7.7                   1-2
# 139           8.8                   1-2
# 140           8.4                   1-8
# 141           7.4                   1-2
# 142           5.9               Up to 4
# 143           8.2              Up to 16
# 144           8.9          not specified
# 145           8.1  No Online Multiplayer
# 146           8.2                   1-4
# 147           8.3          not specified
# 148           8.3               1 Player
# 149           7.7          not specified
# 150           7.0          not specified
# 151           9.2               1 Player
# 152           9.0  No Online Multiplayer
# 153           8.9                   1-2
# 154           8.3              Up to 10
# 155           7.8               1 Player
# 156           5.6               Up to 4
# 157           9.1          not specified
# 158           8.6                   1-2
# 159           8.7                   1-2
# 160           8.2          not specified
# 161           7.3  Massively Multiplayer
# 162           8.9  No Online Multiplayer
# 163           8.4          not specified
#
# [164 rows x 8 columns]

# %%
'''
Metacritic is a well-structured website, so we can modify all game links to guide the scraper directly to the
user reviews page, without having the scraper to click through links.
'''

full_game_user_links = [x + '/user-reviews' for x in full_game_links]

# %%
game_title = []
game_platform = []
usernames = []
userscores = []
comments = []
no_helpfulness = []

# %%
game_count = 0

for index in range(0,4000): # set the number of games you would like the scraper to scrape
    
    game_count += 1
    page_number = 1
    
    driver = webdriver.Chrome(chromedriver)
    driver.implicitly_wait(3)
    driver.get(df['user_reviews_link'][index])

    print(f"Starting to gather comments for {df['Title'][index]}... page {page_number}")
    
    for _ in range(100): #each review page shows a maximum of 100 user reviews; do this to expand longer reviews
        try:
            expand = driver.find_element_by_link_text('Expand')
            expand.click()
        except WebDriverException or NoSuchElementException:
            break
    
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    
    # get username
    for user in soup.find_all('div', attrs={'class':'name'}):
        usernames.append(user.text)
        
    # get user scores
    for grade in soup.find_all('div', attrs={'class':'review_grade'}):
        userscores.append(int(grade.text))
        
    # get comments (need to expand comments)
    for review in soup.find_all('div', attrs={'class':'review_body'}):
        comments.append(review.text.replace('… Collapse', ''))
        game_title.append(df['Title'][index])
        game_platform.append(df['Platform'][index])
    
    # get how helpful a review is
    for vote in soup.find_all('span', attrs={'class':'total_ups'}):
        no_helpfulness.append(vote.text)
   
    for _ in range(100):
        try:
            page_number += 1
            print(f'starting page {page_number}...')
            next_page = driver.find_element_by_link_text('next')
            next_page.click()

            for _ in range(100):
                try:
                    expand = driver.find_element_by_link_text('Expand')
                    expand.click()
                except WebDriverException or NoSuchElementException:
                    break
            
            soup = BeautifulSoup(driver.page_source, 'html.parser')

            # get usernames
            for user in soup.find_all('div', attrs={'class':'name'}):
                usernames.append(user.text)

            # get user scores
            for grade in soup.find_all('div', attrs={'class':'review_grade'}):
                userscores.append(int(grade.text))

            # get comments (need to expand comments)
            for review in soup.find_all('div', attrs={'class':'review_body'}):
                comments.append(review.text.replace('… Collapse', ''))
                game_title.append(df['Title'][index])
                game_platform.append(df['Platform'][index])

            # get how helpful a review is
            for vote in soup.find_all('span', attrs={'class':'total_ups'}):
                no_helpfulness.append(vote.text)
                
        except NoSuchElementException:
            print(f"Finished **{df['Title'][index]}** game # {game_count} - titles: {len(game_title)}; platforms: {len(game_platform)} users: {len(usernames)}; scores: {len(userscores)}")
            print(f"comments: {len(comments)}; helpful rec'd: {len(no_helpfulness)}")
            break
            
    driver.quit()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'user_reviews_link'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-99eba071cf5a> in <module>()
#       8     driver = webdriver.Chrome(chromedriver)
#       9     driver.implicitly_wait(3)
# ---> 10     driver.get(df['user_reviews_link'][index])
#      11
#      12     print(f"Starting to gather comments for {df['Title'][index]}... page {page_number}")
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'user_reviews_link'

# %%
# Save all lists as Pickled files.

with open('actual_game_title_3420.pkl','wb') as titlefile:
    pkl.dump(game_title, titlefile)
    
with open('actual_game_platform_3420.pkl','wb') as platformfile:
    pkl.dump(game_platform, platformfile)
    
with open('actual_usernames_3420.pkl','wb') as userfile:
    pkl.dump(usernames, userfile)
    
with open('actual_userscores_3420.pkl','wb') as scorefile:
    pkl.dump(userscores, scorefile)
    
with open('actual_usercomments_3420.pkl','wb') as commentfile:
    pkl.dump(comments, commentfile)
    
with open('actual_helpfulness_3420.pkl','wb') as helpfulfile:
    pkl.dump(no_helpfulness, helpfulfile)
